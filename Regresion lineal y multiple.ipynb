# %%
# %matplotlib widget

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Generate some example data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 3 + 4 * X + np.random.randn(100, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a Linear Regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
print(f'Los valores de regresión obtenidos son: Pendiente: {model.coef_[0][0]:.3f} - Ordenada: {model.intercept_[0]:.3f}')
# Out:
# Los valores de regresión obtenidos son: Pendiente: 3.936 - Ordenada: 3.322

# %%
r2 = r2_score(y_test, y_pred)

# %%
print(f'El valor de R2 es de {r2:.2f}')
# Out:
# El valor de R2 es de 0.84

# %%
fig, ax = plt.subplots()
ax.scatter(X, y,
           label='Datos originales',
           color='red',
           marker='x',
           s=100,
           alpha=0.5)
ax.plot(X_test, y_pred,
        color='#00000050',
        label='Linear Regression')
ax.set_title('Gráfico')
ax.set_xlabel('Valores en X')
ax.set_ylabel('Valores en y')
ax.grid(True, zorder=99)
plt.legend(loc='lower right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Lo mismo pero Regresión Múltiple

# %%
# Generate some example data with multiple features
np.random.seed(1)
# Create a dataset with 3 features (X1, X2, X3) and a target variable (y)
X = np.random.rand(100, 2)
y = 3 + 2*X[:, 0] + 1.5*X[:, 1] + np.random.randn(100)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a Linear Regression model
model = LinearRegression()

# Fit the model to the training data
# Your code here
model.fit(X_train, y_train)

# Make predictions on the test data
# Your code here
y_pred = model.predict(X_test)

# Print the coefficients of the model (the weights for each feature)
# Your code here
print(f'Coefficients: {model.coef_}')

# Calculate R-squared (R2)
r2 = r2_score(y_test, y_pred)
print(f'R-squared (R2): {r2:.3f}')
# Out:
# Coefficients: [1.9732664  1.80524518]
# R-squared (R2): 0.053

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Create a meshgrid for X1 and X2 values
x1_values = np.linspace(min(X[:, 0]), max(X[:, 0]), 100)
x2_values = np.linspace(min(X[:, 1]), max(X[:, 1]), 100)
X1, X2 = np.meshgrid(x1_values, x2_values)

# Calculate the predicted y values for each combination of X1 and X2
Y = model.intercept_ + model.coef_[0] * X1 + model.coef_[1] * X2

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the data points
ax.scatter(X_test[:, 0], X_test[:, 1], y_test, c='r', marker='o', label='Actual Data')

# Plot the plane corresponding to the coefficients
ax.plot_surface(X1, X2, Y, alpha=0.5, cmap='viridis', label='Fitted Plane')

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
ax.set_title('Linear Regression Plane')

# plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
